# %%
from src import functions as fn
import pandas as pd

# %%
results=pd.read_csv('./data/results_teams.csv')

# %%
fn.column_cleaning(results)

# %%
results = fn.filter(results)

# %%
results = fn.winner(results)

# %%
results_csv=fn.copy(results)

# %%
results_csv
# Out:
#       year         winner
# 0     2002         Norway
# 1     2002       China PR
# 2     2002           draw
# 3     2002         Norway
# 4     2002        Germany
# ...    ...            ...
# 2942  2022         France
# 2943  2022           draw
# 2944  2022  United States
# 2945  2022           draw
# 2946  2022         Norway
#
# [2947 rows x 2 columns]

# %%
results2 = results_csv.groupby(['year', 'winner']).size().groupby(level=0).max()

# %%
results2
# Out:
# year
# 2002    16
# 2003    28
# 2004    25
# 2005    10
# 2006    24
# 2007    20
# 2008    19
# 2009     8
# 2010    15
# 2011    25
# 2012    28
# 2013    21
# 2014    18
# 2015    27
# 2016    33
# 2017    24
# 2018    58
# 2019    20
# 2020     9
# 2021     6
# 2022     5
# dtype: int64

# %%
sizemax = results2.to_frame(name='size').reset_index()

# %%
sizemax.head(50)
# Out:
#     year                  winner  size
# 0   2002                  Angola     3
# 1   2002                Cameroon     3
# 2   2002                  Canada     7
# 3   2002                China PR     5
# 4   2002              Costa Rica     6
# 5   2002                DR Congo     1
# 6   2002                 Denmark     1
# 7   2002      Dominican Republic     1
# 8   2002             El Salvador     1
# 9   2002                 England     1
# 10  2002                Ethiopia     1
# 11  2002                 Finland     1
# 12  2002                   Gabon     2
# 13  2002                 Germany     3
# 14  2002                   Ghana     6
# 15  2002               Guatemala     2
# 16  2002                   Haiti     6
# 17  2002                Honduras     1
# 18  2002                 Jamaica     3
# 19  2002                  Mexico     3
# 20  2002                 Nigeria     4
# 21  2002                  Norway     4
# 22  2002                  Panama     3
# ...

# %%
años = sizemax.year.unique()

for year in años:
    if sizemax[sizemax.size == sizemax.size.max()]:
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
sizemax['count_max'] = sizemax.groupby(['year','winner'])['size'].transform(max)

# %%
sizemax
# Out:
#      year         winner  size  count_max
# 0    2002         Angola     3          3
# 1    2002       Cameroon     3          3
# 2    2002         Canada     7          7
# 3    2002       China PR     5          5
# 4    2002     Costa Rica     6          6
# ..    ...            ...   ...        ...
# 859  2022         Norway     1          1
# 860  2022       Portugal     1          1
# 861  2022         Sweden     1          1
# 862  2022  United States     2          2
# 863  2022           draw     5          5
#
# [864 rows x 4 columns]

# %%
results.to_csv('./data/results.csv', index=False)
