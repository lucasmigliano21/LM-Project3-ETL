# %% [markdown]
# # CLEANING

# %% [markdown]
# ## CSV - DATASET

# %%
import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import warnings
warnings.simplefilter('ignore')
import datetime

# %%
df=pd.read_csv('./data/results.csv')

# %%
df.head()
# Out:
#          date home_team  away_team  home_score  away_score        tournament  \
# 0  1969-11-01     Italy     France           1           0              Euro
# 1  1969-11-01   Denmark    England           4           3              Euro
# 2  1969-11-02   England     France           2           0              Euro
# 3  1969-11-02     Italy    Denmark           3           1              Euro
# 4  1975-08-25  Thailand  Australia           3           2  AFC Championship
#
#         city    country  neutral
# 0     Novara      Italy    False
# 1      Aosta      Italy     True
# 2      Turin      Italy     True
# 3      Turin      Italy    False
# 4  Hong Kong  Hong Kong     True

# %%
df.shape
# Out:
# (4314, 9)

# %%
def dataframe_cleaning(df):
    ''' Changing date to year in order to work with years '''
    df['date'] = df['date'].astype('datetime64')
    df['date'] = df['date'].dt.year
    df.rename(columns = {'date':'year'}, inplace = True)
    ''' As [tournament],[neutral],[city] and [country] columns are not interesting for our purpose, we'll drop them '''
    df.drop(['tournament','neutral','city','country'],axis=1)
    return df

# %%
df
# Out:
#             date                         home_team  \
# 0     1969-11-01                             Italy
# 1     1969-11-01                           Denmark
# 2     1969-11-02                           England
# 3     1969-11-02                             Italy
# 4     1975-08-25                          Thailand
# 5     1975-08-25                         Hong Kong
# 6     1975-08-27                          Thailand
# 7     1975-08-27                       New Zealand
# 8     1975-08-29                         Australia
# 9     1975-08-29                         Hong Kong
# 10    1975-08-31                       New Zealand
# 11    1975-08-31                          Thailand
# 12    1975-09-02                         Australia
# 13    1975-09-02                       New Zealand
# 14    1977-08-02                            Taiwan
# 15    1977-08-03                          Thailand
# 16    1977-08-05                         Indonesia
# 17    1977-08-05                          Thailand
# 18    1977-08-07                            Taiwan
# 19    1977-08-07                         Singapore
# 20    1977-08-09                            Taiwan
# 21    1977-08-09                          Thailand
# 22    1977-08-11                         Singapore
# 23    1977-08-11                            Taiwan
# 24    1979-07-18                             Italy
# 25    1979-07-18                           Denmark
# 26    1979-07-19                           England
# 27    1979-07-19                            Sweden
# 28    1979-07-20                  Northern Ireland
# 29    1979-07-20                            France
# 30    1979-07-21                       Switzerland
# 31    1979-07-21                             Wales
# 32    1979-07-22                             Italy
# 33    1979-07-22                           Denmark
# 34    1979-07-23                           England
# 35    1979-07-23                            Sweden
# 36    1979-07-25                             Italy
# 37    1979-07-25                           Denmark
# 38    1979-07-27                            Sweden
# 39    1979-07-28                             Italy
# 40    1980-01-11                           India S
# 41    1980-01-12                           India N
# 42    1980-01-12                           India S
# 43    1980-01-13                            Taiwan
# 44    1980-01-13                           India N
# 45    1980-01-14                 Western Australia
# 46    1980-01-14                           India N
# 47    1980-01-15                           India S
# 48    1980-01-15                         Hong Kong
# 49    1980-01-16                           India S
# 50    1980-01-16                            Taiwan
# 51    1980-01-17                            Taiwan
# 52    1980-01-17                           India N
# 53    1980-01-18                         Hong Kong
# 54    1980-01-18                           India S
# 55    1980-01-19                            Taiwan
# 56    1980-01-19                           India S
# 57    1980-01-20                           India S
# 58    1981-06-07                         Hong Kong
# 59    1981-06-07                            Taiwan
# 60    1981-06-08                             India
# 61    1981-06-08                          Thailand
# 62    1981-06-10                         Hong Kong
# 63    1981-06-10                             India
# 64    1981-06-11                            Taiwan
# 65    1981-06-11                          Thailand
# 66    1981-06-12                         Hong Kong
# 67    1981-06-12                         Singapore
# 68    1981-06-13                            Taiwan
# 69    1981-06-13                             Japan
# 70    1981-06-15                          Thailand
# 71    1981-06-15                         Hong Kong
# 72    1981-06-17                         Hong Kong
# 73    1981-06-17                          Thailand
# 74    1982-08-18                           Finland
# 75    1982-08-28                            Norway
# 76    1982-09-04                  Northern Ireland
# 77    1982-09-09                           Iceland
# 78    1982-09-15                           Finland
# 79    1982-09-19                           England
# 80    1982-09-19                          Scotland
# 81    1982-09-25                           Belgium
# 82    1982-09-29                            Sweden
# 83    1982-10-02                  Northern Ireland
# 84    1982-10-03                          Scotland
# 85    1982-10-10                       Switzerland
# 86    1982-10-13                       Netherlands
# 87    1982-10-30                            France
# 88    1982-11-06                           Denmark
# 89    1982-11-07               Republic of Ireland
# 90    1982-11-14                             Italy
# 91    1982-12-04                          Portugal
# 92    1983-02-12                            France
# 93    1983-03-05                           Germany
# 94    1983-03-18               Republic of Ireland
# 95    1983-03-19                       Netherlands
# 96    1983-04-03                          Portugal
# 97    1983-04-10                          Thailand
# 98    1983-04-10                             India
# 99    1983-04-10                         Singapore
# 100   1983-04-11                          Thailand
# 101   1983-04-11                             India
# 102   1983-04-11                          Malaysia
# 103   1983-04-12                         Singapore
# 104   1983-04-12                          Thailand
# 105   1983-04-12                             India
# 106   1983-04-14                         Singapore
# 107   1983-04-14                       Philippines
# 108   1983-04-14                          Thailand
# 109   1983-04-15                          Thailand
# 110   1983-04-15                          Malaysia
# 111   1983-04-15                             India
# 112   1983-04-17                          Scotland
# 113   1983-04-17                          Malaysia
# 114   1983-04-17                          Thailand
# 115   1983-04-23                       Netherlands
# 116   1983-04-24                             Italy
# 117   1983-04-30                           Germany
# 118   1983-05-07                            France
# 119   1983-05-14                  Northern Ireland
# 120   1983-05-22                           England
# 121   1983-05-23                       Switzerland
# 122   1983-06-08                            Sweden
# 123   1983-06-24                          Portugal
# 124   1983-07-30                           Iceland
# 125   1983-08-18                            Norway
# 126   1983-08-19                           Belgium
# 127   1983-08-21                           Iceland
# 128   1983-08-24                            Sweden
# 129   1983-08-27                           Finland
# 130   1983-09-11                           England
# 131   1983-09-17                             Italy
# 132   1983-09-24                            Norway
# 133   1983-09-24                           Denmark
# 134   1983-10-08                           Germany
# 135   1983-10-22                           Belgium
# 136   1983-10-23               Republic of Ireland
# 137   1983-10-29                       Switzerland
# 138   1983-10-29                           Denmark
# 139   1983-11-28                     New Caledonia
# 140   1983-11-28                       New Zealand
# 141   1983-11-30                     New Caledonia
# 142   1983-11-30                       New Zealand
# 143   1983-12-02                         Australia
# 144   1983-12-02                     New Caledonia
# 145   1983-12-04                       New Zealand
# 146   1984-04-08                           England
# 147   1984-04-08                             Italy
# 875   1997-03-10                            Sweden
# 876   1997-03-12                            Norway
# 877   1997-03-12                           Denmark
# 878   1997-03-12                          China PR
# 879   1997-03-12                          Portugal
# 880   1997-03-14                            Norway
# 881   1997-03-14                           Finland
# 882   1997-03-14                          China PR
# 883   1997-03-14                          Portugal
# 884   1997-03-16                          Portugal
# 885   1997-03-16                       Netherlands
# 886   1997-03-16                            Sweden
# ...
# 3933                  Ethiopia    False
# 3934                      Mali    False
# 3935              South Africa    False
# 3936                  Zimbabwe    False
# 3937                    Jordan     True
# 3938                    Jordan     True
# 3939                   Ecuador    False
# 3940                   Ecuador     True
# 3941                     Chile     True
# 3942                     Chile     True
# 3943                   Ecuador     True
# 3944                   Ecuador     True
# 3945                     Chile     True
# 3946                     Chile    False
# 3947                    Jordan    False
# 3948                    Jordan     True
# 3949                   Ecuador     True
# 3950                   Ecuador     True
# 3951                     Chile     True
# 3952                     Chile     True
# 3953                    Jordan     True
# 3954                    Jordan     True
# 3955                   Ecuador     True
# 3956                   Ecuador     True
# 3957                     Chile     True
# 3958                     Chile    False
# 3959                    Jordan     True
# 3960                    Jordan     True
# 3961                    Jordan     True
# 3962                   Ecuador     True
# 3963                   Ecuador     True
# 3964                     Chile     True
# 3965                     Chile    False
# 3966                    Jordan     True
# 3967                    Jordan     True
# 3968                   Ecuador     True
# 3969                   Ecuador     True
# 3970                     Chile    False
# 3971                     Chile     True
# 3972        Dominican Republic     True
# 3973        Dominican Republic     True
# 3974        Dominican Republic     True
# 3975                     Haiti     True
# 3976                     Haiti    False
# 3977        Dominican Republic     True
# 3978        Dominican Republic    False
# 3979                     Haiti     True
# 3980                     Haiti    False
# 3981        Dominican Republic     True
# 3982        Dominican Republic    False
# 3983                     Haiti     True
# 3984                     Haiti    False
# 3985       Trinidad and Tobago     True
# 3986       Trinidad and Tobago    False
# 3987       Trinidad and Tobago     True
# 3988       Trinidad and Tobago    False
# 3989       Trinidad and Tobago     True
# 3990       Trinidad and Tobago     True
# 3991       Antigua and Barbuda     True
# 3992       Antigua and Barbuda    False
# 3993                    Guyana     True
# 3994                    Guyana    False
# 3995       Trinidad and Tobago     True
# 3996       Trinidad and Tobago    False
# 3997       Antigua and Barbuda     True
# 3998       Antigua and Barbuda    False
# 3999                    Guyana     True
# 4000                    Guyana    False
# 4001       Trinidad and Tobago     True
# 4002       Trinidad and Tobago    False
# 4003       Antigua and Barbuda     True
# 4004       Antigua and Barbuda    False
# 4005                    Guyana     True
# 4006                    Guyana    False
# 4007                   Nigeria    False
# 4008                     Wales    False
# 4009                  Scotland    False
# 4010                    Sweden    False
# 4011             Faroe Islands    False
# 4012                     Spain    False
# 4013             United States    False
# 4014                    Russia    False
# 4015       Republic of Ireland    False
# 4016          Northern Ireland    False
# 4017                   Ukraine    False
# 4018                     Italy    False
# 4019                   Finland    False
# 4020                   Moldova    False
# 4021                   Iceland    False
# 4022    Bosnia and Herzegovina    False
# 4023                     Wales    False
# 4024                    Poland    False
# 4025                   Belarus    False
# 4026                    Norway    False
# 4027               Netherlands    False
# 4028                   Denmark    False
# 4029                   Ukraine    False
# 4030            Czech Republic    False
# 4031                   Romania    False
# 4032                    Serbia    False
# 4033                    Israel    False
# 4034             United States    False
# 4035                      Fiji     True
# 4036                      Fiji    False
# 4037                   Jamaica     True
# 4038                   Jamaica    False
# 4039                      Fiji     True
# 4040                      Fiji    False
# 4041             United States     True
# 4042             United States     True
# 4043                   Jamaica     True
# 4044                   Jamaica    False
# 4045             United States     True
# 4046             United States     True
# 4047                   Jamaica     True
# 4048                   Jamaica     True
# 4049                      Fiji     True
# 4050                      Fiji    False
# 4051                    Russia    False
# 4052                  Scotland    False
# 4053                    Sweden    False
# 4054                   Denmark    False
# 4055                   Moldova    False
# 4056             United States     True
# 4057             United States     True
# 4058                   Jamaica     True
# 4059                   Jamaica    False
# 4060                     Wales    False
# 4061                   Belarus    False
# 4062       Republic of Ireland    False
# 4063                  Slovakia    False
# 4064            Czech Republic    False
# 4065                   Romania    False
# 4066                     Spain    False
# 4067             United States    False
# 4068                   Iceland    False
# 4069                   Jamaica     True
# 4070                   Jamaica    False
# 4071                    Russia    False
# 4072                Kazakhstan    False
# 4073                    Poland    False
# 4074                   Albania    False
# 4075                    Norway    False
# 4076          Northern Ireland    False
# 4077                   Denmark    False
# 4078                   Ukraine    False
# 4079                   Iceland    False
# 4080             Faroe Islands    False
# 4081                   Belgium    False
# 4082                  Portugal    False
# 4083                   Austria    False
# 4084                     Spain    False
# 4085             United States    False
# 4086             United States     True
# 4087             United States    False
# 4088        Dominican Republic     True
# 4089        Dominican Republic    False
# 4090             United States     True
# 4091             United States     True
# 4092               Netherlands    False
# 4093                   Belgium    False
# 4094             United States    False
# 4095             United States     True
# 4096             United States     True
# 4097             United States     True
# 4098                   Denmark    False
# 4099               Switzerland    False
# 4100             United States     True
# 4101             United States    False
# 4102             United States     True
# 4103             United States     True
# 4104             United States     True
# 4105             United States    False
# 4106             United States     True
# 4107             United States    False
# 4108                  Portugal    False
# 4109                 Argentina    False
# 4110               Netherlands    False
# 4111               Switzerland    False
# 4112                    Panama    False
# 4113                  Scotland    False
# 4114                     Ghana    False
# 4115                     Ghana     True
# 4116                     Ghana     True
# 4117                     Ghana     True
# 4118             New Caledonia     True
# 4119             New Caledonia    False
# 4120             New Caledonia     True
# 4121             New Caledonia    False
# 4122             New Caledonia     True
# 4123             New Caledonia     True
# 4124             New Caledonia     True
# 4125             New Caledonia     True
# 4126                     Ghana    False
# 4127                     Ghana     True
# 4128                     Ghana     True
# 4129                     Ghana     True
# 4130             New Caledonia     True
# 4131             New Caledonia    False
# 4132             New Caledonia     True
# 4133             New Caledonia    False
# 4134             New Caledonia     True
# 4135             New Caledonia     True
# 4136             New Caledonia     True
# 4137             New Caledonia     True
# 4138                     Ghana    False
# 4139                     Ghana     True
# 4140                     Ghana     True
# 4141                     Ghana     True
# 4142             New Caledonia     True
# 4143             New Caledonia    False
# 4144             New Caledonia     True
# 4145             New Caledonia    False
# 4146             New Caledonia     True
# 4147             New Caledonia     True
# 4148             New Caledonia     True
# 4149             New Caledonia     True
# 4150                     Ghana     True
# 4151                     Ghana     True
# 4152             New Caledonia     True
# 4153             New Caledonia    False
# 4154             New Caledonia     True
# 4155             New Caledonia    False
# 4156                     Ghana     True
# 4157                     Ghana     True
# 4158             New Caledonia    False
# 4159             New Caledonia     True
# 4160             New Caledonia    False
# 4161             New Caledonia     True
# 4162                  China PR     True
# 4163                  China PR    False
# 4164                    France    False
# 4165                  China PR     True
# 4166                  China PR    False
# 4167                     Spain    False
# 4168                  Portugal     True
# 4169                  Portugal     True
# 4170                  Portugal     True
# 4171                  Portugal     True
# 4172             United States    False
# 4173             United States     True
# 4174                  Portugal     True
# 4175                  Portugal     True
# 4176                  Portugal     True
# 4177                  Portugal    False
# 4178             United States     True
# 4179             United States    False
# 4180                  Portugal     True
# 4181                  Portugal     True
# 4182                  Portugal     True
# 4183                  Portugal    False
# 4184             United States     True
# 4185             United States    False
# 4186                  Portugal     True
# 4187                  Portugal    False
# 4188                  Portugal     True
# 4189                  Portugal     True
# 4190                  Portugal     True
# 4191                  Portugal     True
# 4192             United States    False
# 4193             United States    False
# 4194             United States    False
# 4195             United States    False
# 4196             United States    False
# 4197                    France    False
# 4198                    France     True
# 4199                    France     True
# 4200                    France     True
# 4201                    France     True
# 4202                    France     True
# 4203                    France     True
# 4204                    France     True
# 4205                    France     True
# 4206                    France     True
# 4207                    France     True
# 4208                    France     True
# 4209                    France     True
# 4210                    France    False
# 4211                    France     True
# 4212                    France     True
# 4213                    France     True
# 4214                    France     True
# 4215                    France     True
# 4216                    France     True
# 4217                    France     True
# 4218                    France     True
# 4219                    France     True
# 4220                    France     True
# 4221                    France    False
# 4222                    France     True
# 4223                    France     True
# 4224                    France     True
# 4225                    France     True
# 4226                    France     True
# 4227                    France     True
# 4228                    France     True
# 4229                    France     True
# 4230                    France     True
# 4231                    France     True
# 4232                    France     True
# 4233                    France     True
# 4234                    France     True
# 4235                    France     True
# 4236                    France    False
# 4237                    France     True
# 4238                    France     True
# 4239                    France     True
# 4240                    France     True
# 4241                    France     True
# 4242                    France    False
# 4243                    France     True
# 4244                    France     True
# 4245                    France     True
# 4246                    France     True
# 4247                    France     True
# 4248                    France     True
# 4249             United States    False
# 4250             United States    False
# 4251             United States    False
# 4252             United States    False
# 4253             United States    False
# 4254             United States    False
# 4255             United States    False
# 4256             United States    False
# 4257             United States    False
# 4258             United States    False
# 4259             United States    False
# 4260             United States    False
# 4261                    France    False
# 4262                    France     True
# 4263                  Portugal     True
# 4264                  Portugal     True
# 4265                  Portugal     True
# 4266                  Portugal    False
# 4267             United States     True
# 4268             United States    False
# 4269                    France     True
# 4270                    France    False
# 4271                  Portugal     True
# 4272                  Portugal    False
# 4273                  Portugal     True
# 4274                  Portugal     True
# 4275                  Portugal    False
# 4276             United States     True
# 4277             United States    False
# 4278                    France     True
# 4279                    France    False
# 4280                  Portugal     True
# 4281                  Portugal     True
# 4282             United States     True
# 4283             United States    False
# 4284               Netherlands    False
# 4285             United States    False
# 4286             United States    False
# 4287             United States    False
# 4288             United States    False
# 4289             United States    False
# 4290                     Spain     True
# 4291                    Sweden    False
# 4292                     Spain     True
# 4293                     Spain     True
# 4294                     Spain     True
# 4295                    France    False
# 4296                    France     True
# 4297                    France    False
# 4298                  Portugal     True
# 4299                  Portugal    False
# 4300             United States    False
# 4301             United States     True
# 4302                    France    False
# 4303                    France     True
# 4304             United States    False
# 4305             United States     True
# 4306                  Portugal     True
# 4307                  Portugal    False
# 4308                    France     True
# 4309                    France    False
# 4310             United States     True
# 4311             United States    False
# 4312                  Portugal     True
# 4313                  Portugal    False

# %%
df.dtypes
# Out:
# date          object
# home_team     object
# away_team     object
# home_score     int64
# away_score     int64
# tournament    object
# city          object
# country       object
# neutral         bool
# dtype: object

# %%
df.head()
# Out:
#    year home_team  away_team  home_score  away_score        tournament  \
# 0  1969     Italy     France           1           0              Euro
# 1  1969   Denmark    England           4           3              Euro
# 2  1969   England     France           2           0              Euro
# 3  1969     Italy    Denmark           3           1              Euro
# 4  1975  Thailand  Australia           3           2  AFC Championship
#
#         city    country  neutral
# 0     Novara      Italy    False
# 1      Aosta      Italy     True
# 2      Turin      Italy     True
# 3      Turin      Italy    False
# 4  Hong Kong  Hong Kong     True

# %%
df = df.drop('neutral',axis=1)

# %%
df =df.loc[df["year"].between(2000, 2021)]
df.reset_index(drop=True, inplace=True)
df.head(5)
# Out:
#    year home_team               away_team  home_score  away_score  \
# 0  2000    Turkey  Bosnia and Herzegovina           3           1
# 1  2000   England                Portugal           2           0
# 2  2000    Greece  Bosnia and Herzegovina           4           0
# 3  2000   England                  Norway           0           3
# 4  2000  Portugal           United States           0           7
#
#                 tournament       city   country
# 0  UEFA Euro qualification   Istanbul    Turkey
# 1  UEFA Euro qualification   Barnsley   England
# 2  UEFA Euro qualification     Greece    Greece
# 3  UEFA Euro qualification    Norwich   England
# 4              Algarve Cup  Albufeira  Portugal

# %%
df['result']=df.home_score - df.away_score

# %%
df.result=df.result.apply(ganar)

# %%
df.head()
# Out:
#    year home_team               away_team  home_score  away_score  \
# 0  2000    Turkey  Bosnia and Herzegovina           3           1
# 1  2000   England                Portugal           2           0
# 2  2000    Greece  Bosnia and Herzegovina           4           0
# 3  2000   England                  Norway           0           3
# 4  2000  Portugal           United States           0           7
#
#                 tournament       city   country result
# 0  UEFA Euro qualification   Istanbul    Turkey   home
# 1  UEFA Euro qualification   Barnsley   England   home
# 2  UEFA Euro qualification     Greece    Greece   home
# 3  UEFA Euro qualification    Norwich   England   away
# 4              Algarve Cup  Albufeira  Portugal   away

# %%
df.dtypes
# Out:
# year           int64
# home_team     object
# away_team     object
# home_score     int64
# away_score     int64
# tournament    object
# city          object
# country       object
# result        object
# dtype: object

# %%
df['winner'] = pd.Series(dtype='str')
df.winner = df.apply(lambda x : x['home_team'] if x['home_score'] > x['away_score'] 
                                              else (x['away_team'] if x['home_score'] < x['away_score'] else 'draw'),
                                              axis=1)
df.head()
# Out:
#    year home_team               away_team  home_score  away_score  \
# 0  2000    Turkey  Bosnia and Herzegovina           3           1
# 1  2000   England                Portugal           2           0
# 2  2000    Greece  Bosnia and Herzegovina           4           0
# 3  2000   England                  Norway           0           3
# 4  2000  Portugal           United States           0           7
#
#                 tournament       city   country result         winner
# 0  UEFA Euro qualification   Istanbul    Turkey   home         Turkey
# 1  UEFA Euro qualification   Barnsley   England   home        England
# 2  UEFA Euro qualification     Greece    Greece   home         Greece
# 3  UEFA Euro qualification    Norwich   England   away         Norway
# 4              Algarve Cup  Albufeira  Portugal   away  United States

# %%
df2 = df[['year', 'winner']].copy()

# %%
df2.to_csv('./data/df2.csv', index=False)

# %%
## not used .... df['points'] = pd.Series(dtype='int')

# %% [markdown]
# # SCRAPING

# %% [markdown]
# ## Method: Selenium

# %%
# %pip install selenium
from selenium import webdriver
# Out:
# Requirement already satisfied: selenium in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (4.1.3)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from selenium) (1.26.7)
# Requirement already satisfied: trio~=0.17 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from selenium) (0.20.0)
# Requirement already satisfied: sniffio in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: outcome in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: async-generator>=1.9 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (3.2)
# Requirement already satisfied: attrs>=19.2.0 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: sortedcontainers in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: wsproto>=0.14 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from trio-websocket~=0.9->selenium) (1.1.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pyOpenSSL>=0.14 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from urllib3[secure,socks]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from urllib3[secure,socks]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: certifi in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from urllib3[secure,socks]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: cffi>=1.12 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium) (1.14.6)
# Requirement already satisfied: pycparser in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium) (2.20)
# Requirement already satisfied: six>=1.5.2 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from pyOpenSSL>=0.14->urllib3[secure,socks]~=1.26->selenium) (1.16.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install webdriver-manager
from webdriver_manager.chrome import ChromeDriverManager
# Out:
# Requirement already satisfied: webdriver-manager in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (3.5.4)
# Requirement already satisfied: requests in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from webdriver-manager) (2.26.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from requests->webdriver-manager) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from requests->webdriver-manager) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from requests->webdriver-manager) (3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium.webdriver.chrome.options import Options

opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False    # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
opciones.add_extension('driver/adblock.crx')       # adblocker
opciones.add_argument('--incognito')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /var/folders/y9/1ck368zx5tq778d5611f3syw0000gn/T/ipykernel_81955/2708606974.py in <module>
#       8 opciones.add_argument('--start-maximized')         # comienza maximizado
#       9 opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
# ---> 10 opciones.add_extension('driver/adblock.crx')       # adblocker
#      11 opciones.add_argument('--incognito')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/chromium/options.py in add_extension(self, extension)
#      99                 self._extension_files.append(extension_to_add)
#     100             else:
# --> 101                 raise IOError("Path to the extension doesn't exist")
#     102         else:
#     103             raise ValueError("argument can not be null")
#
# OSError: Path to the extension doesn't exist

# %%
PATH=ChromeDriverManager().install()
URL='https://www.goal.com/en-in/news/fifa-womens-world-player-of-the-year-award-winners/blt12683887fe8df959'
driver=webdriver.Chrome(PATH)
driver.get(URL)

# %%
acepto=driver.find_element_by_xpath('//*[@id="onetrust-accept-btn-handler"]')

acepto.click()

# %%
tabla = driver.find_element_by_xpath('//*[@id="__next"]/div/main/div/div/article/main/div[3]/div/div[4]')

players = tabla.find_elements_by_tag_name('tr')

players

# %%
lst = []

for i in players:
    i = i.text.replace('\n', ',,,').replace('  ', ',,,').split(',,,')
    lst.append(i)
lst

# %%
import pandas as pd

col_names=lst[0]

data=lst[1:]

df3=pd.DataFrame(data, columns=col_names)

df3.head()

# %%
df3['Club']=[c.replace('Carolina Courage/Birgit Prinz', 'FFC Frankfurt') for c in df3.Club]

df3

# %% [markdown]
# ## BEAUTIFUL SOUP

# %%
import requests as req

from bs4 import BeautifulSoup as bs
url='https://www.topendsports.com/sport/soccer/list-player-of-the-year-women.htm'
html=req.get(url).content

html[:1000]

# %%
soup=bs(html, 'html.parser')

tabla=soup.find('div',{'class':'table-responsive'})
tabla
type(tabla)

# %%
tabla2=tabla.find('table',{'class':'list'})
tabla2

# %%
filas=tabla2.find_all('tr')

filas=[f.text.strip().split('\n') for f in filas]

# %%
col_names=filas[0]

data=filas[1:]

df4=pd.DataFrame(data, columns=col_names)

df4.head()

# %%
df4 = df4.rename(str.title, axis='columns')
df4.head(1)

# %%
df4 = df4.sort_values(by = ['Year'], ascending=True).reset_index().drop('index',axis=1)
df4.head()

# %%
df4['Player']=[c.replace('Nadine Keßler', 'Nadine Kebler') for c in df4.Player]

df4['Player'] = df4['Player'].apply(lambda x: x.strip())
df4
# Out:
#     Year           Player      Nationality
# 0   2001         Mia Hamm    United States
# 1   2002         Mia Hamm    United States
# 2   2003     Birgit Prinz          Germany
# 3   2004     Birgit Prinz          Germany
# 4   2005     Birgit Prinz          Germany
# 5   2006            Marta           Brazil
# 6   2007            Marta           Brazil
# 7   2008            Marta           Brazil
# 8   2009            Marta           Brazil
# 9   2010            Marta           Brazil
# 10  2011      Homare Sawa            Japan
# 11  2012     Abby Wambach              USA
# 12  2013   Nadine Angerer          Germany
# 13  2014    Nadine Kebler          Germany
# 14  2015      Carli Lloyd              USA
# 15  2016      Carli Lloyd              USA
# 16  2017    Lieke Martens  The Netherlands
# 17  2018            Marta           Brazil
# 18  2019    Megan Rapinoe              USA
# 19  2020      Lucy Bronze          England
# 20  2021  Alexia Putellas            Spain

# %%
df5 = pd.merge(df3,df4,how="inner")
df5
# Out:
#     Year           Player                Club      Nationality
# 0   2001         Mia Hamm  Washington Freedom    United States
# 1   2002         Mia Hamm  Washington Freedom    United States
# 2   2003     Birgit Prinz       FFC Frankfurt          Germany
# 3   2004     Birgit Prinz       FFC Frankfurt          Germany
# 4   2005     Birgit Prinz       FFC Frankfurt          Germany
# 5   2006            Marta             Umea IK           Brazil
# 6   2007            Marta             Umea IK           Brazil
# 7   2008            Marta             Umea IK           Brazil
# 8   2009            Marta              Santos           Brazil
# 9   2010            Marta       FC Gold Pride           Brazil
# 10  2011      Homare Sawa  INAC Kobe Leonessa            Japan
# 11  2012     Abby Wambach            W/O club              USA
# 12  2013   Nadine Angerer       Brisbane Roar          Germany
# 13  2014    Nadine Kebler           Wolfsburg          Germany
# 14  2015      Carli Lloyd        Houston Dash              USA
# 15  2016      Carli Lloyd        Houston Dash              USA
# 16  2017    Lieke Martens        FC Barcelona  The Netherlands
# 17  2018            Marta       Orlando Pride           Brazil
# 18  2019    Megan Rapinoe            Reign FC              USA
# 19  2020      Lucy Bronze     Manchester City          England
# 20  2021  Alexia Putellas        FC Barcelona            Spain

# %%
df5['Nationality']=[c.replace('USA', 'United States') for c in df5.Nationality]
df5['Nationality']=[c.replace('The Netherlands', 'Netherlands') for c in df5.Nationality]

# %%
df5['Club'].value_counts()
# Out:
# FFC Frankfurt         3
# Umea IK               3
# Washington Freedom    2
# Houston Dash          2
# FC Barcelona          2
# Santos                1
# FC Gold Pride         1
# INAC Kobe Leonessa    1
# W/O club              1
# Brisbane Roar         1
# Wolfsburg             1
# Orlando Pride         1
# Reign FC              1
# Manchester City       1
# Name: Club, dtype: int64

# %%
df5
# Out:
#     Year           Player                Club    Nationality
# 0   2001         Mia Hamm  Washington Freedom  United States
# 1   2002         Mia Hamm  Washington Freedom  United States
# 2   2003     Birgit Prinz       FFC Frankfurt        Germany
# 3   2004     Birgit Prinz       FFC Frankfurt        Germany
# 4   2005     Birgit Prinz       FFC Frankfurt        Germany
# 5   2006            Marta             Umea IK         Brazil
# 6   2007            Marta             Umea IK         Brazil
# 7   2008            Marta             Umea IK         Brazil
# 8   2009            Marta              Santos         Brazil
# 9   2010            Marta       FC Gold Pride         Brazil
# 10  2011      Homare Sawa  INAC Kobe Leonessa          Japan
# 11  2012     Abby Wambach            W/O club  United States
# 12  2013   Nadine Angerer       Brisbane Roar        Germany
# 13  2014    Nadine Kebler           Wolfsburg        Germany
# 14  2015      Carli Lloyd        Houston Dash  United States
# 15  2016      Carli Lloyd        Houston Dash  United States
# 16  2017    Lieke Martens        FC Barcelona    Netherlands
# 17  2018            Marta       Orlando Pride         Brazil
# 18  2019    Megan Rapinoe            Reign FC  United States
# 19  2020      Lucy Bronze     Manchester City        England
# 20  2021  Alexia Putellas        FC Barcelona          Spain

# %%
df5.to_csv('./data/players.csv', index=False)

# %% [markdown]
# # Selenium

# %%
PATH=ChromeDriverManager().install()
URL='https://www.worldfootball.net/winner/frauen-champions-league/'
driver=webdriver.Chrome(PATH)
driver.get(URL)

acepto=driver.find_element_by_xpath('//*[@id="qc-cmp2-ui"]/div[2]/div/button[2]')
acepto.click()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 100.0.4896
# Get LATEST chromedriver version for 100.0.4896 google-chrome
# Driver [/Users/lucasmigliano/.wdm/drivers/chromedriver/mac64/100.0.4896.60/chromedriver] found in cache

# %%
tabla = driver.find_element_by_xpath('//*[@id="site"]/div[2]/div[1]/div[1]')
tabla
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="98c0aff266bcef30668bdf0bfa86d9d6", element="7b8f7367-6279-4a3e-9a56-ee8ec51c0146")>

# %%
players = tabla.find_elements_by_tag_name('tr')
players
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="98c0aff266bcef30668bdf0bfa86d9d6", element="513d2ba1-2741-4434-ae79-d99f2fd6d316")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="98c0aff266bcef30668bdf0bfa86d9d6", element="c0048cf4-1b62-4687-8c46-da0e1d6cd17b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="98c0aff266bcef30668bdf0bfa86d9d6", element="f594246e-f23f-4c75-852d-e54b7a8a26d3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="98c0aff266bcef30668bdf0bfa86d9d6", element="76936722-04f1-421a-b3ec-fd463081abc5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="98c0aff266bcef30668bdf0bfa86d9d6", element="2b0203e2-0e92-482e-912d-cea56548d2c3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="98c0aff266bcef30668bdf0bfa86d9d6", element="f3c817ce-9d16-4dd1-9620-c1013ae3eb01")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="98c0aff266bcef30668bdf0bfa86d9d6", element="6c1e4903-8bc3-464e-8254-48dd2aef0df0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="98c0aff266bcef30668bdf0bfa86d9d6", element="b401ef0f-b656-4d11-b7e0-4f9781f3d8b2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="98c0aff266bcef30668bdf0bfa86d9d6", element="1928d5d7-cec3-498f-9494-7c91f8f6c313")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="98c0aff266bcef30668bdf0bfa86d9d6", element="dffb42df-1de6-4a51-842c-39f52fa9ad5f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="98c0aff266bcef30668bdf0bfa86d9d6", element="4dd8bef3-6c62-46a6-988a-29e0f4c6737f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="98c0aff266bcef30668bdf0bfa86d9d6", element="3bd1bb43-2cf9-4218-bc50-b26a93c91f1b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="98c0aff266bcef30668bdf0bfa86d9d6", element="d9131f47-4a36-4298-8bb1-9956cb5a9ad1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="98c0aff266bcef30668bdf0bfa86d9d6", element="44a65b72-2dbc-40a5-8369-dba84a87e756")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="98c0aff266bcef30668bdf0bfa86d9d6", element="3531422e-193c-43dc-9f50-5007577dda1a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="98c0aff266bcef30668bdf0bfa86d9d6", element="4fc497e8-41a1-47b9-b828-9523845e6c10")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="98c0aff266bcef30668bdf0bfa86d9d6", element="70bb76b4-394b-4715-aa96-1c5a0eec45e2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="98c0aff266bcef30668bdf0bfa86d9d6", element="b3cb8ada-4702-4224-b6f4-75d98f78a14b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="98c0aff266bcef30668bdf0bfa86d9d6", element="d303856b-a7f5-42cc-8535-eda550714c65")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="98c0aff266bcef30668bdf0bfa86d9d6", element="b3ca77ba-ddba-47c9-931f-3a683b8c168d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="98c0aff266bcef30668bdf0bfa86d9d6", element="df918205-b09d-4f9d-943a-3e1f3561346c")>]

# %%
lst = []

for i in players:
    i = i.text.replace('\n', ',').replace('   ', ',,,').split(' ')
    lst.append(i)
lst

lst[0].append('a')
lst[0].append('b')
lst
# Out:
# [['Year', 'Winner', 'Country', 'a', 'b'],
#  ['2021', 'FC', 'Barcelona', 'Spain'],
#  ['2020', 'Olympique', 'Lyon', 'France'],
#  ['2019', 'Olympique', 'Lyon', 'France'],
#  ['2018', 'Olympique', 'Lyon', 'France'],
#  ['2017', 'Olympique', 'Lyon', 'France'],
#  ['2016', 'Olympique', 'Lyon', 'France'],
#  ['2015', '1.', 'FFC', 'Frankfurt', 'Germany'],
#  ['2014', 'VfL', 'Wolfsburg', 'Germany'],
#  ['2013', 'VfL', 'Wolfsburg', 'Germany'],
#  ['2012', 'Olympique', 'Lyon', 'France'],
#  ['2011', 'Olympique', 'Lyon', 'France'],
#  ['2010', 'Turbine', 'Potsdam', 'Germany'],
#  ['2009', 'FCR', '2001', 'Duisburg', 'Germany'],
#  ['2008', '1.', 'FFC', 'Frankfurt', 'Germany'],
#  ['2007', 'Arsenal', 'LFC', 'England'],
#  ['2006', '1.', 'FFC', 'Frankfurt', 'Germany'],
#  ['2005', 'Turbine', 'Potsdam', 'Germany'],
#  ['2004', 'Umeå', 'IK', 'FF', 'Sweden'],
#  ['2003', 'Umeå', 'IK', 'FF', 'Sweden'],
#  ['2002', '1.', 'FFC', 'Frankfurt', 'Germany']]

# %%
col_names=lst[0]

data=lst[1:]

cham=pd.DataFrame(data, columns=col_names)

cham
# Out:
#     Year     Winner    Country          a        b
# 0   2021         FC  Barcelona      Spain     None
# 1   2020  Olympique       Lyon     France     None
# 2   2019  Olympique       Lyon     France     None
# 3   2018  Olympique       Lyon     France     None
# 4   2017  Olympique       Lyon     France     None
# 5   2016  Olympique       Lyon     France     None
# 6   2015         1.        FFC  Frankfurt  Germany
# 7   2014        VfL  Wolfsburg    Germany     None
# 8   2013        VfL  Wolfsburg    Germany     None
# 9   2012  Olympique       Lyon     France     None
# 10  2011  Olympique       Lyon     France     None
# 11  2010    Turbine    Potsdam    Germany     None
# 12  2009        FCR       2001   Duisburg  Germany
# 13  2008         1.        FFC  Frankfurt  Germany
# 14  2007    Arsenal        LFC    England     None
# 15  2006         1.        FFC  Frankfurt  Germany
# 16  2005    Turbine    Potsdam    Germany     None
# 17  2004       Umeå         IK         FF   Sweden
# 18  2003       Umeå         IK         FF   Sweden
# 19  2002         1.        FFC  Frankfurt  Germany

# %%
cham["Champion"] = cham["Winner"] + " " + cham["Country"]
cham
# Out:
#     Year     Winner    Country          a        b         Champion
# 0   2021         FC  Barcelona      Spain     None     FC Barcelona
# 1   2020  Olympique       Lyon     France     None   Olympique Lyon
# 2   2019  Olympique       Lyon     France     None   Olympique Lyon
# 3   2018  Olympique       Lyon     France     None   Olympique Lyon
# 4   2017  Olympique       Lyon     France     None   Olympique Lyon
# 5   2016  Olympique       Lyon     France     None   Olympique Lyon
# 6   2015         1.        FFC  Frankfurt  Germany           1. FFC
# 7   2014        VfL  Wolfsburg    Germany     None    VfL Wolfsburg
# 8   2013        VfL  Wolfsburg    Germany     None    VfL Wolfsburg
# 9   2012  Olympique       Lyon     France     None   Olympique Lyon
# 10  2011  Olympique       Lyon     France     None   Olympique Lyon
# 11  2010    Turbine    Potsdam    Germany     None  Turbine Potsdam
# 12  2009        FCR       2001   Duisburg  Germany         FCR 2001
# 13  2008         1.        FFC  Frankfurt  Germany           1. FFC
# 14  2007    Arsenal        LFC    England     None      Arsenal LFC
# 15  2006         1.        FFC  Frankfurt  Germany           1. FFC
# 16  2005    Turbine    Potsdam    Germany     None  Turbine Potsdam
# 17  2004       Umeå         IK         FF   Sweden          Umeå IK
# 18  2003       Umeå         IK         FF   Sweden          Umeå IK
# 19  2002         1.        FFC  Frankfurt  Germany           1. FFC

# %%
cham['Champion']=[c.replace('1. FFC', 'FFC Frankfurt') for c in cham.Champion]
cham['Champion']=[c.replace('1.', 'FFC Frankfurt') for c in cham.Champion]
cham = cham.drop(['Winner','Country'], axis=1)
cham.head()
# Out:
#    Year       a     b        Champion
# 0  2021   Spain  None    FC Barcelona
# 1  2020  France  None  Olympique Lyon
# 2  2019  France  None  Olympique Lyon
# 3  2018  France  None  Olympique Lyon
# 4  2017  France  None  Olympique Lyon

# %%
cham['a']=[c.replace('Frankfurt', 'Germany') for c in cham.a]
cham['a']=[c.replace('Duisburg', 'Germany') for c in cham.a]
cham['a']=[c.replace('FF', 'Sweden') for c in cham.a]
cham = cham.drop('b', axis=1)
cham.head()
# Out:
#    Year       a        Champion
# 0  2021   Spain    FC Barcelona
# 1  2020  France  Olympique Lyon
# 2  2019  France  Olympique Lyon
# 3  2018  France  Olympique Lyon
# 4  2017  France  Olympique Lyon

# %%
cham.rename(columns = {'a':'Country'}, inplace = True)
cham = cham.sort_values(by = ['Year'], ascending=True).reset_index().drop('index',axis=1)
cham['Champion']=[c.replace('Umeå IK', 'Umea IK') for c in cham.Champion]
cham['Champion']=[c.replace('VfL Wolfsburg', 'Wolfsburg') for c in cham.Champion]
cham
# Out:
#     Year  Country         Champion
# 0   2002  Germany    FFC Frankfurt
# 1   2003   Sweden          Umea IK
# 2   2004   Sweden          Umea IK
# 3   2005  Germany  Turbine Potsdam
# 4   2006  Germany    FFC Frankfurt
# 5   2007  England      Arsenal LFC
# 6   2008  Germany    FFC Frankfurt
# 7   2009  Germany         FCR 2001
# 8   2010  Germany  Turbine Potsdam
# 9   2011   France   Olympique Lyon
# 10  2012   France   Olympique Lyon
# 11  2013  Germany        Wolfsburg
# 12  2014  Germany        Wolfsburg
# 13  2015  Germany    FFC Frankfurt
# 14  2016   France   Olympique Lyon
# 15  2017   France   Olympique Lyon
# 16  2018   France   Olympique Lyon
# 17  2019   France   Olympique Lyon
# 18  2020   France   Olympique Lyon
# 19  2021    Spain     FC Barcelona

# %%
cham.to_csv('./data/champions.csv', index=False)
